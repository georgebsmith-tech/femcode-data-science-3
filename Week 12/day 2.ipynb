# %%
import pandas as pd

# %%
df = pd.read_csv("drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# %matplotlib inline
df.plot(kind="box")

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America
# 6                           8.3  South America
# 7                           3.8         Europe
# 8                          10.4        Oceania
# 9                           9.7         Europe

# %%
## Method one for

# %%
df["beer_servings"].max()
# Out:
# 376

# %%
df["beer_servings"]==df["beer_servings"].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: beer_servings, Length: 193, dtype: bool

# %%
df[df["beer_servings"]==df["beer_servings"].max()]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %% [markdown]
# ## minimum

# %%
df[df["beer_servings"]==df["beer_servings"].min()]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 40       Cook Islands              0              254             74
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# 149      Saudi Arabia              0                5              0
# 158           Somalia              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0      Asia
# 13                            0.0      Asia
# 40                            5.9   Oceania
# 46                            0.0      Asia
# 79                            0.0      Asia
# 90                            0.0      Asia
# 97                            0.0    Africa
# 103                           0.0      Asia
# 106                           0.0   Oceania
# 107                           0.0    Africa
# 111                           0.0    Europe
# 128                           0.0      Asia
# 147                           0.0    Europe
# 149                           0.1      Asia
# 158                           0.0    Africa

# %%
df[df["beer_servings"]==df["beer_servings"].min()].shape
# Out:
# (15, 6)

# %% [markdown]
# ## method 2

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.beer_servings.sort_values(ascending=False)
# Out:
# 117    376
# 45     361
# 62     347
# 65     346
# 135    343
# 98     343
# 188    333
# 81     313
# 129    306
# 140    297
# 16     295
# 130    285
# 160    284
# 151    283
# 93     281
# 9      279
# 156    270
# 17     263
# 60     263
# 8      261
# 120    251
# 184    249
# 141    247
# 23     245
# 3      245
# 32     240
# 109    238
# 99     236
# 75     234
# 76     233
#       ...
# 178      6
# 86       6
# 190      6
# 53       6
# 78       5
# 104      5
# 167      5
# 116      5
# 119      5
# 123      3
# 168      2
# 73       1
# 171      1
# 38       1
# 137      1
# 46       0
# 158      0
# 107      0
# 149      0
# 13       0
# 147      0
# 128      0
# 111      0
# 106      0
# 103      0
# 97       0
# 90       0
# 79       0
# 40       0
# 0        0
# Name: beer_servings, Length: 193, dtype: int64

# %%
df["total_cons"]=df.beer_servings+df.wine_servings+df.spirit_servings+df.total_litres_of_pure_alcohol

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_cons
# 0                           0.0      Asia         0.0
# 1                           4.9    Europe       279.9
# 2                           0.7    Africa        39.7
# 3                          12.4    Europe       707.4
# 4                           5.9    Africa       324.9

# %%
## alternatively

# %%
df.iloc[:,1:5].head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
df.iloc[:,1:5].sum()
# Out:
# beer_servings                   20489.0
# spirit_servings                 15632.0
# wine_servings                    9544.0
# total_litres_of_pure_alcohol      910.4
# dtype: float64

# %%
df.iloc[:,1:5].sum(axis=1)
# Out:
# 0        0.0
# 1      279.9
# 2       39.7
# 3      707.4
# 4      324.9
# 5      279.9
# 6      447.3
# 7      214.8
# 8      555.4
# 9      554.7
# 10      73.3
# 11     355.3
# 12     114.0
# 13       0.0
# 14     358.3
# 15     571.4
# 16     601.5
# 17     391.8
# 18      52.1
# 19      23.4
# 20     219.8
# 21     261.6
# 22     248.4
# 23     413.2
# 24      34.6
# 25     587.3
# 26      43.3
# 27      94.3
# 28      49.0
# 29     220.0
#        ...
# 163    318.6
# 164     98.7
# 165    405.2
# 166    575.2
# 167     57.0
# 168     17.3
# 169    364.4
# 170    222.9
# 171      6.1
# 172     58.3
# 173     63.1
# 174    366.4
# 175     75.3
# 176     81.4
# 177    124.2
# 178     57.0
# 179     62.3
# 180    496.9
# 181    158.8
# 182    550.4
# 183     48.7
# 184    499.7
# 185    376.6
# 186    136.4
# 187     50.9
# 188    443.7
# 189    116.0
# 190      6.1
# 191     57.5
# 192     90.7
# Length: 193, dtype: float64

# %% [markdown]
# ## Review in numpy

# %%
import numpy as np

# %%
x=np.random.randint(12,40,(3,4))

# %%
x
# Out:
# array([[37, 31, 18, 23],
#        [14, 26, 28, 22],
#        [26, 21, 32, 30]])

# %%
x.sum()
# Out:
# 308

# %%
x.sum(axis=0)
# Out:
# array([77, 78, 78, 75])

# %%
x.sum(axis=1)
# Out:
# array([109,  90, 109])

# %%
df["mod_sum"]=df.iloc[:,1:5].sum(axis=1)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_cons  mod_sum
# 0                           0.0      Asia         0.0      0.0
# 1                           4.9    Europe       279.9    279.9
# 2                           0.7    Africa        39.7     39.7
# 3                          12.4    Europe       707.4    707.4
# 4                           5.9    Africa       324.9    324.9

# %%
df.drop(["mod_sum"],axis=1,inplace=True)

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_cons
# 0                           0.0      Asia         0.0
# 1                           4.9    Europe       279.9
# 2                           0.7    Africa        39.7
# 3                          12.4    Europe       707.4
# 4                           5.9    Africa       324.9

# %%
df.total_cons.max()
# Out:
# 707.4

# %%
# df.iloc[1:5,:].sum()

# %%
df.total_cons==df.total_cons.max()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: total_cons, Length: 193, dtype: bool

# %%
df[df.total_cons==df.total_cons.max()]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_cons
# 3                          12.4    Europe       707.4

# %%
df[df.total_cons==df.total_cons.min()]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# 158           Somalia              0                0              0
#
#      total_litres_of_pure_alcohol continent  total_cons
# 0                             0.0      Asia         0.0
# 13                            0.0      Asia         0.0
# 46                            0.0      Asia         0.0
# 79                            0.0      Asia         0.0
# 90                            0.0      Asia         0.0
# 97                            0.0    Africa         0.0
# 103                           0.0      Asia         0.0
# 106                           0.0   Oceania         0.0
# 107                           0.0    Africa         0.0
# 111                           0.0    Europe         0.0
# 128                           0.0      Asia         0.0
# 147                           0.0    Europe         0.0
# 158                           0.0    Africa         0.0
