# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../datasets/drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.set_index("country")
# Out:
#                       beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                       0                0              0
# Albania                          89              132             54
# Algeria                          25                0             14
# Andorra                         245              138            312
# Angola                          217               57             45
# Antigua & Barbuda               102              128             45
# Argentina                       193               25            221
# Armenia                          21              179             11
# Australia                       261               72            212
# Austria                         279               75            191
# Azerbaijan                       21               46              5
# Bahamas                         122              176             51
# Bahrain                          42               63              7
# ...

# %%
df.set_index(["country","continent"])
# Out:
#                                     beer_servings  spirit_servings  \
# country              continent
# Afghanistan          Asia                       0                0
# Albania              Europe                    89              132
# Algeria              Africa                    25                0
# Andorra              Europe                   245              138
# Angola               Africa                   217               57
# Antigua & Barbuda    North America            102              128
# Argentina            South America            193               25
# Armenia              Europe                    21              179
# Australia            Oceania                  261               72
# Austria              Europe                   279               75
# Azerbaijan           Europe                    21               46
# Bahamas              North America            122              176
# ...

# %%
df.set_index(["continent","country"])
# Out:
#                                     beer_servings  spirit_servings  \
# continent     country
# Asia          Afghanistan                       0                0
# Europe        Albania                          89              132
# Africa        Algeria                          25                0
# Europe        Andorra                         245              138
# Africa        Angola                          217               57
# North America Antigua & Barbuda               102              128
# South America Argentina                       193               25
# Europe        Armenia                          21              179
# Oceania       Australia                       261               72
# Europe        Austria                         279               75
#               Azerbaijan                       21               46
# North America Bahamas                         122              176
# Asia          Bahrain                          42               63
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df1=df.set_index(["continent","country"])

# %%
df1.head(10)
# Out:
#                                  beer_servings  spirit_servings  \
# continent     country
# Asia          Afghanistan                    0                0
# Europe        Albania                       89              132
# Africa        Algeria                       25                0
# Europe        Andorra                      245              138
# Africa        Angola                       217               57
# North America Antigua & Barbuda            102              128
# South America Argentina                    193               25
# Europe        Armenia                       21              179
# Oceania       Australia                    261               72
# Europe        Austria                      279               75
#
#                                  wine_servings  total_litres_of_pure_alcohol
# continent     country
# Asia          Afghanistan                    0                           0.0
# ...

# %%
df2=df1.sort_index()

# %%
df2.head()
# Out:
#                         beer_servings  spirit_servings  wine_servings  \
# continent country
# Africa    Algeria                  25                0             14
#           Angola                  217               57             45
#           Benin                    34                4             13
#           Botswana                173               35             35
#           Burkina Faso             25                7              7
#
#                         total_litres_of_pure_alcohol
# continent country
# Africa    Algeria                                0.7
#           Angola                                 5.9
#           Benin                                  1.1
#           Botswana                               5.4
#           Burkina Faso                           4.3

# %%
df["continent"]=="Africa"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 163    False
# 164     True
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175     True
# 176    False
# 177    False
# 178    False
# 179     True
# 180    False
# 181    False
# 182    False
# 183     True
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191     True
# 192     True
# Name: continent, Length: 193, dtype: bool

# %%
df_Africa=df[df["continent"]=="Africa"]

# %%
df_Africa.shape
# Out:
# (53, 6)

# %%
df_Africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 2 to 192
# Data columns (total 6 columns):
# country                         53 non-null object
# beer_servings                   53 non-null int64
# spirit_servings                 53 non-null int64
# wine_servings                   53 non-null int64
# total_litres_of_pure_alcohol    53 non-null float64
# continent                       53 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
df_Africa["country"]=="Nigeria"
# Out:
# 2      False
# 4      False
# 18     False
# 22     False
# 26     False
# 27     False
# 28     False
# 29     False
# 31     False
# 33     False
# 34     False
# 38     False
# 39     False
# 47     False
# 49     False
# 53     False
# 55     False
# 56     False
# 58     False
# 62     False
# 63     False
# 66     False
# 70     False
# 71     False
# 88     False
# 95     False
# 96     False
# 97     False
# 100    False
# 101    False
# 104    False
# 107    False
# 108    False
# 114    False
# 115    False
# 117    False
# 123    False
# 124     True
# 142    False
# 148    False
# 150    False
# 152    False
# 153    False
# 158    False
# 159    False
# 162    False
# 164    False
# 172    False
# 175    False
# 179    False
# 183    False
# 191    False
# 192    False
# Name: country, dtype: bool

# %%
df_Africa[df_Africa["country"]=="Nigeria"]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 124  Nigeria             42                5              2
#
#      total_litres_of_pure_alcohol continent
# 124                           9.1    Africa

# %%
df_Nigeria=df_Africa[df_Africa["country"]=="Nigeria"]

# %%
df_Nigeria
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 124  Nigeria             42                5              2
#
#      total_litres_of_pure_alcohol continent
# 124                           9.1    Africa

# %%
df_Nigeria.plot(kind="bar")

# %%
df_Nigeria.set_index("country").plot(kind="bar")
